# %% [markdown]
# # Designing the Scraper for watchfinder.com

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
import time

# %%
def url_to_soup(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    return soup

# %%
def extract_watch_data(soup):
    # Extract Model and Reference Code
    model = soup.find('meta', {'itemprop': 'model'}).get('content', 'N/A')
    reference_code = soup.find('meta', {'itemprop': 'mpn'}).get('content', 'N/A')

    # Extract Price
    price_span = soup.find('span', {'class': 'h2 bold reduced-padding'})
    price = price_span.text.strip() if price_span else 'N/A'

    # Extract Specifications
    specs_table = soup.find('div', {'id': 'specification-content'}).find('table')
    specifications = {}

    # Loop through each row of the table
    for row in specs_table.find_all('tr'):
        cols = row.find_all('td')
        if len(cols) == 2:
            name = cols[0].text.strip().replace(':', '')
            value = cols[1].text.strip()
            specifications[name] = value

    # Display the extracted data
    watch_data = {
        "Model": model,
        "Reference Code": reference_code,
        "Price": price,
        "Specifications": specifications
    }

    return watch_data

# %%
def clean_watch_data(watch_data_dict):
    # Helper function to clean individual strings
    def clean_text(text):
        # Lowercase "MM"
        text = re.sub(r'\bMM\b', 'mm', text)
        # Convert "metres" to "m"
        text = re.sub(r'\bmetres\b', 'm', text)
        # Remove \r and \n
        text = text.replace('\r', '').replace('\n', '')
        # Remove extra whitespaces
        text = re.sub(r'\s+', ' ', text).strip()
        return text
    
    # Clean Model and Reference Code
    watch_data_dict['Model'] = clean_text(watch_data_dict.get('Model', 'N/A'))
    watch_data_dict['Reference Code'] = clean_text(watch_data_dict.get('Reference Code', 'N/A'))
    watch_data_dict['Price'] = clean_text(watch_data_dict.get('Price', 'N/A'))
    # Remove dollar sign and comma thousands separator from Price
    watch_data_dict['Price'] = re.sub(r'[$,]', '', watch_data_dict['Price'])
    
    # Clean Specifications
    cleaned_specs = {}
    for key, value in watch_data_dict.get('Specifications', {}).items():
        cleaned_key = clean_text(key)
        cleaned_value = clean_text(value)
        cleaned_specs[cleaned_key] = cleaned_value
        
    watch_data_dict['Specifications'] = cleaned_specs
    
    return watch_data_dict

# %%
def extract_item_links(soup):
    """
    Extracts href links from a BeautifulSoup object and filters them to keep only those containing '/item/'.
    
    Args:
        soup (BeautifulSoup): A BeautifulSoup object containing the parsed HTML.

    Returns:
        list: A list of href links containing '/item/'.
    """
    links = []

    # Find all anchor tags with href attributes
    anchor_tags = soup.find_all('a', href=True)

    # Filter links containing '/item/'
    for tag in anchor_tags:
        href = tag['href']
        if '/item/' in href:
            links.append(href)
    
    return links

# %%
product_list_url = 'https://www.watchfinder.com/Tag%20Heuer/Carrera/watches'

# %%
class SeleniumSoupMaker:
    def __init__(self):
            # Set up Chrome options
            chrome_options = Options()
            chrome_options.add_argument("--headless")  # Run in headless mode (no browser window)
            chrome_options.add_argument("--no-sandbox")
            chrome_options.add_argument("--disable-dev-shm-usage")

            # Use local ChromeDriver path
            driver_path = "/usr/local/bin/chromedriver-mac-arm64/chromedriver"
            self.driver = webdriver.Chrome(service=ChromeService(driver_path), options=chrome_options)


    def get_soup(self, url):
            # Open the webpage
            self.driver.get(url)

            time.sleep(2)

            # Get the full page HTML
            html = self.driver.page_source
            soup = BeautifulSoup(html, 'html.parser')

            return soup

    def close(self):
            self.driver.quit()

# %%
def extract_watch_data(soup):
    # Extract Model and Reference Code
    model = soup.find('meta', {'itemprop': 'model'}).get('content', 'N/A')
    reference_code = soup.find('meta', {'itemprop': 'mpn'}).get('content', 'N/A')

    # Extract Price
    price_span = soup.find('span', {'class': 'h2 bold reduced-padding'})
    price = price_span.text.strip() if price_span else 'N/A'

    # If no regular price, check for discounted price
    if price == 'N/A':
        discount_price_span = soup.find('span', {'class': 'h2 bold reduced-padding with-saving'})
        price = discount_price_span.text.strip() if discount_price_span else 'N/A'

    # Extract Specifications
    specs_table = soup.find('div', {'id': 'specification-content'}).find('table')
    specifications = {}

    # Loop through each row of the table
    for row in specs_table.find_all('tr'):
        cols = row.find_all('td')
        if len(cols) == 2:
            name = cols[0].text.strip().replace(':', '')
            value = cols[1].text.strip()
            specifications[name] = value

    # Display the extracted data
    watch_data = {
        "Model": model,
        "Reference Code": reference_code,
        "Price": price,
        "Specifications": specifications
    }

    return watch_data

# %%
collections = [
    'Carrera',
    'Monaco',
    'Aquaracer',
    'F1',
    'Link',
    'Autavia'
]

# Define list to store all watch links
watch_links = []

chrome_bot = SeleniumSoupMaker()

for collection in collections:
    print(f'Getting links to watches in the {collection} collection...')
    collection_base_url = f'https://www.watchfinder.com/Tag%20Heuer/{collection}/watches'
    
    for i in range(1, 6):
        watches_url = collection_base_url + f'?pageno={i}'
        watches_soup = chrome_bot.get_soup(watches_url)
        item_links = extract_item_links(watches_soup)
        watch_links.extend(item_links)

# Remove duplicates from watch_links
watch_links = list(set(watch_links))
print(f'Found {len(watch_links)} unique watch links.')

# Close the Chrome bot
chrome_bot.close()
# Out:
# Getting links to watches in the Carrera collection...
# Getting links to watches in the Monaco collection...
# Getting links to watches in the Aquaracer collection...
# Getting links to watches in the F1 collection...
# Getting links to watches in the Link collection...
# Getting links to watches in the Autavia collection...
# Found 395 unique watch links.

# %%
watch_results = []

print('Extracting data for each watch...')
for link in watch_links:
    url = 'https://www.watchfinder.com' + link
    soup = url_to_soup(url)
    watch_data = extract_watch_data(soup)
    cleaned_watch_data = clean_watch_data(watch_data)
    
    # Create a dictionary for the current watch data
    watch_entry = {
        'URL': url,
        'Model': cleaned_watch_data['Model'],
        'Reference Code': cleaned_watch_data['Reference Code'],
        'Price': cleaned_watch_data['Price']
    }
    
    # Flatten the specifications dictionary
    for spec_key, spec_value in cleaned_watch_data['Specifications'].items():
        watch_entry[spec_key] = spec_value
    
    print(watch_entry)
    watch_results.append(watch_entry)

print('Extraction complete!')

print('Converting data to DataFrame...')
# Convert the list of dictionaries to a DataFrame
results_df = pd.DataFrame(watch_results)
print('Data conversion complete!')
# Out:
# Extracting data for each watch...
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/CAJ2110.FT6023/17960/item/294035', 'Model': 'Aquaracer', 'Reference Code': 'CAJ2110.FT6023', 'Price': '2165', 'Box': 'Yes', 'Year': '2020', 'Product code': '294035', 'Case size': '44 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '500 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR201V.BA0714/37894/item/332374', 'Model': 'Carrera', 'Reference Code': 'CAR201V.BA0714', 'Price': '3910', 'Box': 'Yes', 'Year': '2020', 'Product code': '332374', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Skeleton Black Dial', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WV215D.BD0788/28663/item/311026', 'Model': 'Carrera', 'Reference Code': 'WV215D.BD0788', 'Price': '2785', 'Box': 'Yes', 'Year': '2016', 'Product code': '311026', 'Case size': '39 mm', 'Case material': 'Steel & Yellow Gold', 'Bracelet': 'Steel & Yellow Gold (length 16.5 cm)', 'Dial type': 'Silver Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2A11.BA0799/26885/item/318617', 'Model': 'Carrera', 'Reference Code': 'CAR2A11.BA0799', 'Price': '3000', 'Box': 'No', 'Year': '2015', 'Product code': '318617', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Grey Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV2014.BA0786/29301/item/316410', 'Model': 'Carrera', 'Reference Code': 'CV2014.BA0786', 'Price': '2525', 'Box': 'No', 'Year': '2008', 'Product code': '316410', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Black Baton', 'Water resistance': '50 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CW2111.FC6177/1551/item/335128', 'Model': 'Monaco', 'Reference Code': 'CW2111.FC6177', 'Price': '3310', 'Box': 'Yes', 'Year': '2015', 'Product code': '335128', 'Case size': '38 mm', 'Case material': 'Steel', 'Dial type': 'Black Baton', 'Water resistance': '30 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Formula%201/WAZ201A.FC8195/30708/item/325406', 'Model': 'Formula 1', 'Reference Code': 'WAZ201A.FC8195', 'Price': '1420', 'Box': 'Yes', 'Year': '2015', 'Product code': '325406', 'Case size': '43 mm', 'Case material': 'Titanium', 'Bracelet': 'Calf - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WV211A.FC6181/12957/item/318504', 'Model': 'Carrera', 'Reference Code': 'WV211A.FC6181', 'Price': '1505', 'Box': 'Yes', 'Year': '2001', 'Product code': '318504', 'Case size': '39 mm', 'Case material': 'Steel', 'Dial type': 'Silver Baton', 'Water resistance': '50 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN2A1E.BA0643/50342/item/334816', 'Model': 'Carrera', 'Reference Code': 'CBN2A1E.BA0643', 'Price': '5350', 'Box': 'Yes', 'Year': '2021', 'Product code': '334816', 'Case size': '44 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (Adjustable)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WBP201D.FT6197/54056/item/322488', 'Model': 'Aquaracer', 'Reference Code': 'WBP201D.FT6197', 'Price': '2350', 'Box': 'No', 'Year': '2022', 'Product code': '322488', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'White', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2113.FC6177/55591/item/287194', 'Model': 'Monaco', 'Reference Code': 'CBL2113.FC6177', 'Price': '5855', 'Box': 'Yes', 'Year': '2022', 'Product code': '287194', 'Case size': '39 mm', 'Case material': 'Steel', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WAY211A.BA0928/29555/item/317693', 'Model': 'Aquaracer', 'Reference Code': 'WAY211A.BA0928', 'Price': '2300', 'Box': 'Yes', 'Year': '2019', 'Product code': '317693', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 15 cm)', 'Dial type': 'Black Baton', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WBP231G.FT6226/58185/item/329261', 'Model': 'Aquaracer', 'Reference Code': 'WBP231G.FT6226', 'Price': '2705', 'Box': 'Yes', 'Year': '2022', 'Product code': '329261', 'Case size': '36 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Turquoise (Adjustable)', 'Dial type': 'Turquoise Diamond', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/CAY2110.BA0925/27477/item/306879', 'Model': 'Aquaracer', 'Reference Code': 'CAY2110.BA0925', 'Price': '2420', 'Box': 'Yes', 'Year': '2022', 'Product code': '306879', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Black Baton', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2184.FT6236/58791/item/317397', 'Model': 'Monaco', 'Reference Code': 'CBL2184.FT6236', 'Price': '11005', 'Box': 'Yes', 'Year': '2023', 'Product code': '317397', 'Case size': '39 mm', 'Case material': 'Titanium', 'Bracelet': 'Leather - Black & Rubber (Adjustable)', 'Dial type': 'Skeleton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW2111.FC6183/50064/item/334916', 'Model': 'Monaco', 'Reference Code': 'CAW2111.FC6183', 'Price': '4780', 'Box': 'No', 'Year': '2015', 'Product code': '334916', 'Case size': '39 mm', 'Case material': 'Steel', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2C12.FC6327/27246/item/244800', 'Model': 'Carrera', 'Reference Code': 'CAR2C12.FC6327', 'Price': '4780', 'Box': 'Yes', 'Year': '2015', 'Product code': '244800', 'Case size': '45 mm', 'Case material': 'Steel', 'Dial type': 'Grey Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WBN2110.BA0639/55578/item/330891', 'Model': 'Carrera', 'Reference Code': 'WBN2110.BA0639', 'Price': '2645', 'Box': 'Yes', 'Year': '2025', 'Product code': '330891', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 15.2 cm)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW211P.FC6356/28477/item/327150', 'Model': 'Monaco', 'Reference Code': 'CAW211P.FC6356', 'Price': '5295', 'Box': 'Yes', 'Year': '2022', 'Product code': '327150', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV2A1AB.BA0738/34680/item/307281', 'Model': 'Carrera', 'Reference Code': 'CV2A1AB.BA0738', 'Price': '2085', 'Box': 'Yes', 'Year': '2020', 'Product code': '307281', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Black Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN2A1B.BA0643/49867/item/321558', 'Model': 'Carrera', 'Reference Code': 'CBN2A1B.BA0643', 'Price': '3910', 'Box': 'Yes', 'Year': '2023', 'Product code': '321558', 'Case size': '44 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 16 cm)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBS5010.FC6543/58316/item/279089', 'Model': 'Carrera', 'Reference Code': 'CBS5010.FC6543', 'Price': '16720', 'Box': 'No', 'Year': '2023', 'Product code': '279089', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Blue (length 15 cm)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WAS2111.FC6293/24492/item/335658', 'Model': 'Carrera', 'Reference Code': 'WAS2111.FC6293', 'Price': '2105', 'Box': 'Yes', 'Year': '2012', 'Product code': '335658', 'Case size': '41 mm', 'Case material': 'Steel', 'Dial type': 'Silver Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2A1Z.FT6044/29627/item/309846', 'Model': 'Carrera', 'Reference Code': 'CAR2A1Z.FT6044', 'Price': '3730', 'Box': 'Yes', 'Year': '2018', 'Product code': '309846', 'Case size': '45 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'Skeleton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW218C.FC6548/59737/item/315019', 'Model': 'Monaco', 'Reference Code': 'CAW218C.FC6548', 'Price': '8360', 'Box': 'Yes', 'Year': '2023', 'Product code': '315019', 'Case size': '39 mm', 'Case material': 'Titanium', 'Bracelet': 'Leather - Blue (Adjustable)', 'Dial type': 'Silver', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Formula%201%20Sparkling/WAU2213.BA0861/23987/item/318772', 'Model': 'Formula 1 Sparkling', 'Reference Code': 'WAU2213.BA0861', 'Price': '2570', 'Box': 'Yes', 'Year': '2020', 'Product code': '318772', 'Case size': '37 mm', 'Case material': 'Ceramic', 'Bracelet': 'Ceramic & Steel (length 12.1 cm)', 'Dial type': 'White Diamond', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Link/CAT2012.BA0952/28142/item/294809', 'Model': 'Link', 'Reference Code': 'CAT2012.BA0952', 'Price': '2335', 'Box': 'Yes', 'Year': '2013', 'Product code': '294809', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 17.5 cm)', 'Dial type': 'Black Dial, Black Sub Dials', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV211A.FC6335/29402/item/330331', 'Model': 'Carrera', 'Reference Code': 'CV211A.FC6335', 'Price': '4885', 'Box': 'Yes', 'Year': '2015', 'Product code': '330331', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Blue (Adjustable)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WBN201A.BA0640/55510/item/316037', 'Model': 'Carrera', 'Reference Code': 'WBN201A.BA0640', 'Price': '3345', 'Box': 'Yes', 'Year': '2023', 'Product code': '316037', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WAR5010.FC6266/28898/item/304772', 'Model': 'Carrera', 'Reference Code': 'WAR5010.FC6266', 'Price': '3005', 'Box': 'Yes', 'Year': '2023', 'Product code': '304772', 'Case size': '41 mm', 'Case material': 'Steel', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2113.FC6177/55591/item/340440', 'Model': 'Monaco', 'Reference Code': 'CBL2113.FC6177', 'Price': '5985', 'Box': 'Yes', 'Year': '2023', 'Product code': '340440', 'Case size': '39 mm', 'Case material': 'Steel', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Formula%201%20Sparkling/WAH1212.BA0859/16682/item/326459', 'Model': 'Formula 1 Sparkling', 'Reference Code': 'WAH1212.BA0859', 'Price': '1505', 'Box': 'No', 'Year': '2001', 'Product code': '326459', 'Case size': '35 mm', 'Case material': 'Ceramic', 'Bracelet': 'Ceramic - Black & Steel (length 15.2 cm)', 'Dial type': 'Black Baton', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV201AP.FC6429/39302/item/330476', 'Model': 'Carrera', 'Reference Code': 'CV201AP.FC6429', 'Price': '3235', 'Box': 'Yes', 'Year': '2022', 'Product code': '330476', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBK2110.FC6266/43910/item/321869', 'Model': 'Carrera', 'Reference Code': 'CBK2110.FC6266', 'Price': '2700', 'Box': 'Yes', 'Year': '2020', 'Product code': '321869', 'Case size': '41 mm', 'Case material': 'Steel', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WAP1112.BA0831/21378/item/323573', 'Model': 'Aquaracer', 'Reference Code': 'WAP1112.BA0831', 'Price': '1025', 'Box': 'Yes', 'Year': '2012', 'Product code': '323573', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Blue Baton', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN2A1F.FC6492/50096/item/333886', 'Model': 'Carrera', 'Reference Code': 'CBN2A1F.FC6492', 'Price': '5115', 'Box': 'Yes', 'Year': '2024', 'Product code': '333886', 'Case size': '44 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Grey', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera%20Ladies/WBG1315.FC6412/38730/item/327176', 'Model': 'Carrera Ladies', 'Reference Code': 'WBG1315.FC6412', 'Price': '2855', 'Box': 'Yes', 'Year': '2015', 'Product code': '327176', 'Case size': '36 mm', 'Case material': 'Steel', 'Bracelet': 'Alligator - White (Adjustable)', 'Dial type': 'Mother of Pearl White - Diamond', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WAR201B.BA0723/26261/item/324410', 'Model': 'Carrera', 'Reference Code': 'WAR201B.BA0723', 'Price': '2405', 'Box': 'Yes', 'Year': '2021', 'Product code': '324410', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Silver Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2C11.FC6327/24482/item/266972', 'Model': 'Carrera', 'Reference Code': 'CAR2C11.FC6327', 'Price': '3585', 'Box': 'Yes', 'Year': '2013', 'Product code': '266972', 'Case size': '45 mm', 'Case material': 'Steel', 'Dial type': 'Grey & Silver', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBK2112.BA0715/38077/item/283446', 'Model': 'Carrera', 'Reference Code': 'CBK2112.BA0715', 'Price': '3345', 'Box': 'Yes', 'Year': '2021', 'Product code': '283446', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18.5 cm)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera%20Ladies/WAR2413.BA0776/37187/item/306597', 'Model': 'Carrera Ladies', 'Reference Code': 'WAR2413.BA0776', 'Price': '2435', 'Box': 'Yes', 'Year': '2019', 'Product code': '306597', 'Case size': '28 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 15 cm)', 'Dial type': 'Black Diamond', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN2012/60049/item/302566', 'Model': 'Carrera', 'Reference Code': 'CBN2012', 'Price': '3735', 'Box': 'Yes', 'Year': '2020', 'Product code': '302566', 'Case size': '42 mm', 'Case material': 'Steel', 'Dial type': 'Grey Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN201D.FC6543/58318/item/330571', 'Model': 'Carrera', 'Reference Code': 'CBN201D.FC6543', 'Price': '4115', 'Box': 'Yes', 'Year': '2023', 'Product code': '330571', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Blue (Adjustable)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WV211B.BA0787/2928/item/324505', 'Model': 'Carrera', 'Reference Code': 'WV211B.BA0787', 'Price': '1680', 'Box': 'No', 'Year': '2008', 'Product code': '324505', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Black Baton', 'Water resistance': '50 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/CAJ2111.BA0872/50256/item/216610', 'Model': 'Aquaracer', 'Reference Code': 'CAJ2111.BA0872', 'Price': '2175', 'Box': 'Yes', 'Year': '2018', 'Product code': '216610', 'Case size': '44 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 19 cm)', 'Dial type': 'Black Baton', 'Water resistance': '500 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW211E.FC6414/52634/item/244949', 'Model': 'Monaco', 'Reference Code': 'CAW211E.FC6414', 'Price': '10960', 'Box': 'Yes', 'Year': '2021', 'Product code': '244949', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Green (Adjustable)', 'Dial type': 'Green', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Grand%20Carrera/WAV5111.BA0901/8805/item/321105', 'Model': 'Grand Carrera', 'Reference Code': 'WAV5111.BA0901', 'Price': '2040', 'Box': 'Yes', 'Year': '2012', 'Product code': '321105', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WV3010.EB0025/9097/item/313127', 'Model': 'Carrera', 'Reference Code': 'WV3010.EB0025', 'Price': '2335', 'Box': 'Yes', 'Year': '2011', 'Product code': '313127', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '50 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBG2A1Z.BA0658/40542/item/327531', 'Model': 'Carrera', 'Reference Code': 'CBG2A1Z.BA0658', 'Price': '5370', 'Box': 'Yes', 'Year': '2022', 'Product code': '327531', 'Case size': '45 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18.5 cm)', 'Dial type': 'Skeleton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2182.FT6235/58789/item/333425', 'Model': 'Monaco', 'Reference Code': 'CBL2182.FT6235', 'Price': '9160', 'Box': 'Yes', 'Year': '2024', 'Product code': '333425', 'Case size': '39 mm', 'Case material': 'Titanium', 'Bracelet': 'Leather & Rubber (Adjustable)', 'Dial type': 'Skeleton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBM2112.BA0651/41871/item/334987', 'Model': 'Carrera', 'Reference Code': 'CBM2112.BA0651', 'Price': '3520', 'Box': 'Yes', 'Year': '2022', 'Product code': '334987', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 17.5 cm)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WBP201D.FT6197/54056/item/311536', 'Model': 'Aquaracer', 'Reference Code': 'WBP201D.FT6197', 'Price': '2605', 'Box': 'Yes', 'Year': '2023', 'Product code': '311536', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'White', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW2111.FC6183/62871/item/321439', 'Model': 'Monaco', 'Reference Code': 'CAW2111.FC6183', 'Price': '4630', 'Box': 'Yes', 'Year': '2014', 'Product code': '321439', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Calf - Blue (Adjustable)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2110.FC6266/17967/item/303550', 'Model': 'Carrera', 'Reference Code': 'CAR2110.FC6266', 'Price': '2275', 'Box': 'Yes', 'Year': '2017', 'Product code': '303550', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Crocodile - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CW2113.FC6183/39642/item/326740', 'Model': 'Monaco', 'Reference Code': 'CW2113.FC6183', 'Price': '3910', 'Box': 'Yes', 'Year': '2007', 'Product code': '326740', 'Case size': '38 mm', 'Case material': 'Steel', 'Dial type': 'Blue Baton', 'Water resistance': '30 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Autavia/CBE511B.FC8279/61023/item/325688', 'Model': 'Autavia', 'Reference Code': 'CBE511B.FC8279', 'Price': '4790', 'Box': 'Yes', 'Year': '2023', 'Product code': '325688', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Alligator - Black (Adjustable)', 'Dial type': 'Silver Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2111.FC6453/46594/item/323658', 'Model': 'Monaco', 'Reference Code': 'CBL2111.FC6453', 'Price': '5530', 'Box': 'Yes', 'Year': '2022', 'Product code': '323658', 'Case size': '39 mm', 'Case material': 'Steel', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAL5111.FC6299/26107/item/333428', 'Model': 'Monaco', 'Reference Code': 'CAL5111.FC6299', 'Price': '8000', 'Box': 'Yes', 'Year': '2015', 'Product code': '333428', 'Case size': '40 mm', 'Case material': 'Steel', 'Dial type': 'Blue', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WBN2113.BA0639/55576/item/306594', 'Model': 'Carrera', 'Reference Code': 'WBN2113.BA0639', 'Price': '2765', 'Box': 'Yes', 'Year': '2024', 'Product code': '306594', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 16 cm)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW211P.FC6356/28477/item/334219', 'Model': 'Monaco', 'Reference Code': 'CAW211P.FC6356', 'Price': '4805', 'Box': 'Yes', 'Year': '2024', 'Product code': '334219', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2182.FT6235/58789/item/339130', 'Model': 'Monaco', 'Reference Code': 'CBL2182.FT6235', 'Price': '10160', 'Box': 'Yes', 'Year': '2023', 'Product code': '339130', 'Case size': '39 mm', 'Case material': 'Titanium', 'Bracelet': 'Leather & Rubber (Adjustable)', 'Dial type': 'Skeleton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WAS2140.FC8176/24044/item/311071', 'Model': 'Carrera', 'Reference Code': 'WAS2140.FC8176', 'Price': '4990', 'Box': 'Yes', 'Year': '2021', 'Product code': '311071', 'Case size': '39 mm', 'Case material': 'Rose Gold', 'Dial type': 'Silver Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBS2014.FT6293/62575/item/321924', 'Model': 'Carrera', 'Reference Code': 'CBS2014.FT6293', 'Price': '8360', 'Box': 'Yes', 'Year': '2025', 'Product code': '321924', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV2A1V.BA0738/36193/item/325789', 'Model': 'Carrera', 'Reference Code': 'CV2A1V.BA0738', 'Price': '3020', 'Box': 'Yes', 'Year': '2022', 'Product code': '325789', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Blue Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN2A1F.FC6492/50096/item/319027', 'Model': 'Carrera', 'Reference Code': 'CBN2A1F.FC6492', 'Price': '5015', 'Box': 'Yes', 'Year': '2022', 'Product code': '319027', 'Case size': '44 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (length 17.5 cm)', 'Dial type': 'Grey', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WBP201D.FT6197/54056/item/335631', 'Model': 'Aquaracer', 'Reference Code': 'WBP201D.FT6197', 'Price': '2760', 'Box': 'Yes', 'Year': '2023', 'Product code': '335631', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'White', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBG2010.FT6143/49933/item/317405', 'Model': 'Carrera', 'Reference Code': 'CBG2010.FT6143', 'Price': '3965', 'Box': 'Yes', 'Year': '2023', 'Product code': '317405', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Black (length 17.5 cm)', 'Dial type': 'Skeleton Black Dial', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN2A1F.FC6492/50096/item/330786', 'Model': 'Carrera', 'Reference Code': 'CBN2A1F.FC6492', 'Price': '4750', 'Box': 'Yes', 'Year': '2021', 'Product code': '330786', 'Case size': '44 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Grey', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN2019.BA0642/59303/item/288025', 'Model': 'Carrera', 'Reference Code': 'CBN2019.BA0642', 'Price': '5365', 'Box': 'Yes', 'Year': '2022', 'Product code': '288025', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18.5 cm)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2113.FC6177/55591/item/249599', 'Model': 'Monaco', 'Reference Code': 'CBL2113.FC6177', 'Price': '6125', 'Box': 'Yes', 'Year': '2023', 'Product code': '249599', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Alligator - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBK2112.BA0715/38077/item/297037', 'Model': 'Carrera', 'Reference Code': 'CBK2112.BA0715', 'Price': '3550', 'Box': 'No', 'Year': '2022', 'Product code': '297037', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 19 cm)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBG2A90.FT6173/56194/item/302028', 'Model': 'Carrera', 'Reference Code': 'CBG2A90.FT6173', 'Price': '5475', 'Box': 'Yes', 'Year': '2021', 'Product code': '302028', 'Case size': '45 mm', 'Case material': 'Ceramic', 'Bracelet': 'Rubber - Black (length 17.5 cm)', 'Dial type': 'Skeleton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Link/CJF211A.BA0594/15278/item/327767', 'Model': 'Link', 'Reference Code': 'CJF211A.BA0594', 'Price': '2450', 'Box': 'No', 'Year': '2010', 'Product code': '327767', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Black Baton', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Link/WJF1354.BB0581/3651/item/334966', 'Model': 'Link', 'Reference Code': 'WJF1354.BB0581', 'Price': '2045', 'Box': 'No', 'Year': '2001', 'Product code': '334966', 'Case size': '27 mm', 'Case material': 'Steel & Yellow Gold', 'Bracelet': 'Steel & Yellow Gold (length 16.5 cm)', 'Dial type': 'Mother of Pearl White - Diamond', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV2A10.FC6235/12790/item/318306', 'Model': 'Carrera', 'Reference Code': 'CV2A10.FC6235', 'Price': '2760', 'Box': 'No', 'Year': '2009', 'Product code': '318306', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Leather Alligator Grain - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Formula%201/CAU2011.BA0873/24937/item/312459', 'Model': 'Formula 1', 'Reference Code': 'CAU2011.BA0873', 'Price': '2190', 'Box': 'Yes', 'Year': '2001', 'Product code': '312459', 'Case size': '44 mm', 'Case material': 'Steel', 'Bracelet': 'Ceramic & Steel (length 18 cm)', 'Dial type': 'Grey Baton', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Autavia/CBE2118.FC8246/60403/item/333232', 'Model': 'Autavia', 'Reference Code': 'CBE2118.FC8246', 'Price': '4885', 'Box': 'Yes', 'Year': '2023', 'Product code': '333232', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Black', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2012.BA0796/25415/item/319505', 'Model': 'Carrera', 'Reference Code': 'CAR2012.BA0796', 'Price': '2580', 'Box': 'Yes', 'Year': '2013', 'Product code': '319505', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 16 cm)', 'Dial type': 'White Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Link/CAT2010.BA0952/22174/item/336470', 'Model': 'Link', 'Reference Code': 'CAT2010.BA0952', 'Price': '1840', 'Box': 'No', 'Year': '2014', 'Product code': '336470', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18.5 cm)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2A1H.FT6101/37307/item/308093', 'Model': 'Carrera', 'Reference Code': 'CAR2A1H.FT6101', 'Price': '4270', 'Box': 'Yes', 'Year': '2022', 'Product code': '308093', 'Case size': '45 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black & Rubber (Adjustable)', 'Dial type': 'Black Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV2010.BA0794/10071/item/315668', 'Model': 'Carrera', 'Reference Code': 'CV2010.BA0794', 'Price': '1870', 'Box': 'Yes', 'Year': '2010', 'Product code': '315668', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 17.5 cm)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV2010.FC6233/10072/item/320371', 'Model': 'Carrera', 'Reference Code': 'CV2010.FC6233', 'Price': '2465', 'Box': 'No', 'Year': '2015', 'Product code': '320371', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR201T.BA0766/34751/item/313158', 'Model': 'Carrera', 'Reference Code': 'CAR201T.BA0766', 'Price': '3725', 'Box': 'Yes', 'Year': '2021', 'Product code': '313158', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18.5 cm)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2C12.FC6327/27246/item/255995', 'Model': 'Carrera', 'Reference Code': 'CAR2C12.FC6327', 'Price': '3320', 'Box': 'Yes', 'Year': '2016', 'Product code': '255995', 'Case size': '45 mm', 'Case material': 'Steel', 'Dial type': 'Grey Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Formula%201/CAH1113.BA0850/5606/item/331310', 'Model': 'Formula 1', 'Reference Code': 'CAH1113.BA0850', 'Price': '1505', 'Box': 'No', 'Year': '2001', 'Product code': '331310', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Orange Baton', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2A5A.FT6044/33192/item/244818', 'Model': 'Carrera', 'Reference Code': 'CAR2A5A.FT6044', 'Price': '5865', 'Box': 'No', 'Year': '2020', 'Product code': '244818', 'Case size': '45 mm', 'Case material': 'Rose Gold', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WBN2111.BA0639/54515/item/332001', 'Model': 'Carrera', 'Reference Code': 'WBN2111.BA0639', 'Price': '1990', 'Box': 'Yes', 'Year': '2023', 'Product code': '332001', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 17 cm)', 'Dial type': 'Silver Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/CAF2011.BA0815/5243/item/306677', 'Model': 'Aquaracer', 'Reference Code': 'CAF2011.BA0815', 'Price': '1730', 'Box': 'Yes', 'Year': '2001', 'Product code': '306677', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Silver Baton', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Formula%201/WAZ2014.BA0842/38079/item/327514', 'Model': 'Formula 1', 'Reference Code': 'WAZ2014.BA0842', 'Price': '1885', 'Box': 'Yes', 'Year': '2023', 'Product code': '327514', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 16.5 cm)', 'Dial type': 'Blue Baton', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW2111.FC6183/50064/item/314556', 'Model': 'Monaco', 'Reference Code': 'CAW2111.FC6183', 'Price': '4870', 'Box': 'Yes', 'Year': '2015', 'Product code': '314556', 'Case size': '39 mm', 'Case material': 'Steel', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WAK211A.BA0830/28545/item/326400', 'Model': 'Aquaracer', 'Reference Code': 'WAK211A.BA0830', 'Price': '2380', 'Box': 'Yes', 'Year': '2016', 'Product code': '326400', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18.5 cm)', 'Dial type': 'Black Baton', 'Water resistance': '500 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2113.FC6177/55591/item/330580', 'Model': 'Monaco', 'Reference Code': 'CBL2113.FC6177', 'Price': '5955', 'Box': 'Yes', 'Year': '2024', 'Product code': '330580', 'Case size': '39 mm', 'Case material': 'Steel', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Grand%20Carrera/WAV5111.BA0901/8805/item/326441', 'Model': 'Grand Carrera', 'Reference Code': 'WAV5111.BA0901', 'Price': '1890', 'Box': 'No', 'Year': '2008', 'Product code': '326441', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WBP208C.FT6201/53548/item/309451', 'Model': 'Aquaracer', 'Reference Code': 'WBP208C.FT6201', 'Price': '3430', 'Box': 'Yes', 'Year': '2021', 'Product code': '309451', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'Black', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2115.FC6494/55537/item/319536', 'Model': 'Monaco', 'Reference Code': 'CBL2115.FC6494', 'Price': '5695', 'Box': 'Yes', 'Year': '2023', 'Product code': '319536', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Blue (Adjustable)', 'Dial type': 'Blue', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Formula%201/WAZ2011.BA0843/32347/item/332486', 'Model': 'Formula 1', 'Reference Code': 'WAZ2011.BA0843', 'Price': '2400', 'Box': 'Yes', 'Year': '2023', 'Product code': '332486', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Ceramic - Black & Steel (length 17.5 cm)', 'Dial type': 'Anthracite', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR201V.BA0714/37894/item/318502', 'Model': 'Carrera', 'Reference Code': 'CAR201V.BA0714', 'Price': '3790', 'Box': 'Yes', 'Year': '2019', 'Product code': '318502', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 19 cm)', 'Dial type': 'Skeleton Black Dial', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV2A1R.FC6235/30956/item/320522', 'Model': 'Carrera', 'Reference Code': 'CV2A1R.FC6235', 'Price': '3100', 'Box': 'Yes', 'Year': '2017', 'Product code': '320522', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Crocodile - Black (Adjustable)', 'Dial type': 'Black', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV2A84.FC6394/33368/item/330607', 'Model': 'Carrera', 'Reference Code': 'CV2A84.FC6394', 'Price': '3120', 'Box': 'Yes', 'Year': '2019', 'Product code': '330607', 'Case size': '43 mm', 'Case material': 'Titanium', 'Bracelet': 'Leather - Brown (Adjustable)', 'Dial type': 'Black Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/CAY2112.BA0927/30950/item/294823', 'Model': 'Aquaracer', 'Reference Code': 'CAY2112.BA0927', 'Price': '2005', 'Box': 'No', 'Year': '2018', 'Product code': '294823', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Blue Baton', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAL5111.FC6299/26107/item/305160', 'Model': 'Monaco', 'Reference Code': 'CAL5111.FC6299', 'Price': '8000', 'Box': 'Yes', 'Year': '2015', 'Product code': '305160', 'Case size': '40 mm', 'Case material': 'Steel', 'Dial type': 'Blue', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Autavia/CBE511B.FC8279/61023/item/336775', 'Model': 'Autavia', 'Reference Code': 'CBE511B.FC8279', 'Price': '5045', 'Box': 'Yes', 'Year': '2023', 'Product code': '336775', 'Case size': '42 mm', 'Case material': 'Steel', 'Dial type': 'Silver Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2116.FC6497/51108/item/260509', 'Model': 'Monaco', 'Reference Code': 'CBL2116.FC6497', 'Price': '8720', 'Box': 'Yes', 'Year': '2021', 'Product code': '260509', 'Case size': '39 mm', 'Case material': 'Steel', 'Dial type': 'Green Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CW2112.FC6177/1555/item/330585', 'Model': 'Monaco', 'Reference Code': 'CW2112.FC6177', 'Price': '2945', 'Box': 'No', 'Year': '2002', 'Product code': '330585', 'Case size': '38 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Silver Baton', 'Water resistance': '30 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Grand%20Carrera/WAV5113.BA0901/8810/item/325890', 'Model': 'Grand Carrera', 'Reference Code': 'WAV5113.BA0901', 'Price': '2500', 'Box': 'Yes', 'Year': '2008', 'Product code': '325890', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18.5 cm)', 'Dial type': 'Brown Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WBP2110.BA0627/56833/item/317101', 'Model': 'Aquaracer', 'Reference Code': 'WBP2110.BA0627', 'Price': '1995', 'Box': 'Yes', 'Year': '2023', 'Product code': '317101', 'Case size': '40 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 17.5 cm)', 'Dial type': 'Black Baton', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBS2211.FC6545/62707/item/331025', 'Model': 'Carrera', 'Reference Code': 'CBS2211.FC6545', 'Price': '5310', 'Box': 'Yes', 'Year': '2024', 'Product code': '331025', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Green Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV2010.BA0794/10071/item/307726', 'Model': 'Carrera', 'Reference Code': 'CV2010.BA0794', 'Price': '2300', 'Box': 'Yes', 'Year': '2013', 'Product code': '307726', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 17.5 cm)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2A1N.FT6100/35247/item/255287', 'Model': 'Carrera', 'Reference Code': 'CAR2A1N.FT6100', 'Price': '3360', 'Box': 'Yes', 'Year': '2017', 'Product code': '255287', 'Case size': '45 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Blue & Black Rubber (Adjustable)', 'Dial type': 'Blue Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera%20Ladies/WAR2416.BA0776/35824/item/311689', 'Model': 'Carrera Ladies', 'Reference Code': 'WAR2416.BA0776', 'Price': '1685', 'Box': 'No', 'Year': '2020', 'Product code': '311689', 'Case size': '28 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 14.5 cm)', 'Dial type': 'Silver Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2B10.FC6235/34261/item/281923', 'Model': 'Carrera', 'Reference Code': 'CAR2B10.FC6235', 'Price': '4360', 'Box': 'Yes', 'Year': '2014', 'Product code': '281923', 'Case size': '43 mm', 'Case material': 'Steel', 'Dial type': 'Black', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2113.BA0644/51936/item/338995', 'Model': 'Monaco', 'Reference Code': 'CBL2113.BA0644', 'Price': '5085', 'Box': 'Yes', 'Year': '2020', 'Product code': '338995', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Formula%201/WAZ2011.BA0843/32347/item/198699', 'Model': 'Formula 1', 'Reference Code': 'WAZ2011.BA0843', 'Price': '2170', 'Box': 'Yes', 'Year': '2020', 'Product code': '198699', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Ceramic - Black & Steel (length 18 cm)', 'Dial type': 'Anthracite', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WBN2111.FC6505/55539/item/334008', 'Model': 'Carrera', 'Reference Code': 'WBN2111.FC6505', 'Price': '2570', 'Box': 'Yes', 'Year': '2024', 'Product code': '334008', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Alligator - Black (Adjustable)', 'Dial type': 'Silver Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WBP2010.FT6198/58181/item/318246', 'Model': 'Aquaracer', 'Reference Code': 'WBP2010.FT6198', 'Price': '2750', 'Box': 'No', 'Year': '2023', 'Product code': '318246', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Blue (Adjustable)', 'Dial type': 'Blue', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Formula%201/WAZ2011.BA0843/32347/item/325736', 'Model': 'Formula 1', 'Reference Code': 'WAZ2011.BA0843', 'Price': '2170', 'Box': 'Yes', 'Year': '2020', 'Product code': '325736', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Ceramic - Black & Steel (length 17.5 cm)', 'Dial type': 'Anthracite', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Grand%20Carrera/WAV5111.BA0901/8805/item/311884', 'Model': 'Grand Carrera', 'Reference Code': 'WAV5111.BA0901', 'Price': '1890', 'Box': 'No', 'Year': '2008', 'Product code': '311884', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 17.5 cm)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV2A1M.BA0796/25211/item/318454', 'Model': 'Carrera', 'Reference Code': 'CV2A1M.BA0796', 'Price': '3055', 'Box': 'No', 'Year': '2017', 'Product code': '318454', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Anthracite', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WAF1312.BA0817/8675/item/334234', 'Model': 'Aquaracer', 'Reference Code': 'WAF1312.BA0817', 'Price': '1255', 'Box': 'Yes', 'Year': '2001', 'Product code': '334234', 'Case size': '32 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 13 cm)', 'Dial type': 'Mother of Pearl White - Diamond', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2A1W.BA0703/30969/item/320398', 'Model': 'Carrera', 'Reference Code': 'CAR2A1W.BA0703', 'Price': '3550', 'Box': 'No', 'Year': '2018', 'Product code': '320398', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Skeleton Black Dial', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Link/CJF7110.BA0592/10069/item/326444', 'Model': 'Link', 'Reference Code': 'CJF7110.BA0592', 'Price': '1345', 'Box': 'Yes', 'Year': '2015', 'Product code': '326444', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 17.1 cm)', 'Dial type': 'Black Baton', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN2A1F.FC6492/50096/item/323459', 'Model': 'Carrera', 'Reference Code': 'CBN2A1F.FC6492', 'Price': '4750', 'Box': 'Yes', 'Year': '2021', 'Product code': '323459', 'Case size': '44 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Grey', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WBP201D.FT6197/54056/item/325421', 'Model': 'Aquaracer', 'Reference Code': 'WBP201D.FT6197', 'Price': '2760', 'Box': 'Yes', 'Year': '2023', 'Product code': '325421', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'White', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2110.FC6266/17967/item/318506', 'Model': 'Carrera', 'Reference Code': 'CAR2110.FC6266', 'Price': '2525', 'Box': 'Yes', 'Year': '2014', 'Product code': '318506', 'Case size': '41 mm', 'Case material': 'Steel', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WAY211A.BA0928/29555/item/330598', 'Model': 'Aquaracer', 'Reference Code': 'WAY211A.BA0928', 'Price': '2105', 'Box': 'Yes', 'Year': '2015', 'Product code': '330598', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Black Baton', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV211D.BA0739/35020/item/329186', 'Model': 'Carrera', 'Reference Code': 'CV211D.BA0739', 'Price': '3550', 'Box': 'Yes', 'Year': '2018', 'Product code': '329186', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN2A1AA.FT6228/58183/item/334533', 'Model': 'Carrera', 'Reference Code': 'CBN2A1AA.FT6228', 'Price': '3550', 'Box': 'Yes', 'Year': '2022', 'Product code': '334533', 'Case size': '44 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'Black', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WBP1110.BA0627/55571/item/336082', 'Model': 'Aquaracer', 'Reference Code': 'WBP1110.BA0627', 'Price': '1460', 'Box': 'No', 'Year': '2022', 'Product code': '336082', 'Case size': '40 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 16.5 cm)', 'Dial type': 'Black Baton', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV201AS.FC6429/44761/item/319619', 'Model': 'Carrera', 'Reference Code': 'CV201AS.FC6429', 'Price': '3070', 'Box': 'Yes', 'Year': '2024', 'Product code': '319619', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBG2A10.BA0654/50580/item/302840', 'Model': 'Carrera', 'Reference Code': 'CBG2A10.BA0654', 'Price': '4840', 'Box': 'Yes', 'Year': '2020', 'Product code': '302840', 'Case size': '45 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18.5 cm)', 'Dial type': 'Skeleton Black Dial', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Grand%20Carrera/CAV518B.FC6237/9091/item/303809', 'Model': 'Grand Carrera', 'Reference Code': 'CAV518B.FC6237', 'Price': '2605', 'Box': 'Yes', 'Year': '2001', 'Product code': '303809', 'Case size': '43 mm', 'Case material': 'Titanium', 'Dial type': 'Black Dial, Black Sub Dials', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2A1J.FC6400/61269/item/260224', 'Model': 'Carrera', 'Reference Code': 'CAR2A1J.FC6400', 'Price': '4750', 'Box': 'Yes', 'Year': '2018', 'Product code': '260224', 'Case size': '45 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'Skeleton', 'Water resistance': '100 m'}
# ...
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CW2111.FC6177/1551/item/340562', 'Model': 'Monaco', 'Reference Code': 'CW2111.FC6177', 'Price': '2975', 'Box': 'Yes', 'Year': '2015', 'Product code': '340562', 'Case size': '38 mm', 'Case material': 'Steel', 'Bracelet': 'Crocodile - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '30 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/CAP2111.BA0833/21579/item/329686', 'Model': 'Aquaracer', 'Reference Code': 'CAP2111.BA0833', 'Price': '1625', 'Box': 'Yes', 'Year': '2017', 'Product code': '329686', 'Case size': '44 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Silver Baton', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW2111.FC6183/14266/item/314384', 'Model': 'Monaco', 'Reference Code': 'CAW2111.FC6183', 'Price': '4255', 'Box': 'Yes', 'Year': '2011', 'Product code': '314384', 'Case size': '39 mm', 'Case material': 'Steel', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN2A10.BA0643/49220/item/314539', 'Model': 'Carrera', 'Reference Code': 'CBN2A10.BA0643', 'Price': '4795', 'Box': 'Yes', 'Year': '2022', 'Product code': '314539', 'Case size': '44 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 17 cm)', 'Dial type': 'Green Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW218B.FC6496/51825/item/316452', 'Model': 'Monaco', 'Reference Code': 'CAW218B.FC6496', 'Price': '8675', 'Box': 'Yes', 'Year': '2022', 'Product code': '316452', 'Case size': '39 mm', 'Case material': 'Titanium', 'Dial type': 'Silver Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WBP201F.BA0632/55535/item/331679', 'Model': 'Aquaracer', 'Reference Code': 'WBP201F.BA0632', 'Price': '2125', 'Box': 'Yes', 'Year': '2024', 'Product code': '331679', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 20 cm)', 'Dial type': 'Orange', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2C12.FC6327/27246/item/244451', 'Model': 'Carrera', 'Reference Code': 'CAR2C12.FC6327', 'Price': '3160', 'Box': 'Yes', 'Year': '2018', 'Product code': '244451', 'Case size': '45 mm', 'Case material': 'Steel', 'Dial type': 'Grey Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera%20Ladies/WAR1114.BA0601/38110/item/325208', 'Model': 'Carrera Ladies', 'Reference Code': 'WAR1114.BA0601', 'Price': '2940', 'Box': 'Yes', 'Year': '2021', 'Product code': '325208', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR5A8K.FT6172/38880/item/247611', 'Model': 'Carrera', 'Reference Code': 'CAR5A8K.FT6172', 'Price': '17985', 'Box': 'Yes', 'Year': '2022', 'Product code': '247611', 'Case size': '45 mm', 'Case material': 'Titanium', 'Bracelet': 'Leather - Black & Rubber (Adjustable)', 'Dial type': 'Skeleton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW2111.FC6183/50064/item/320524', 'Model': 'Monaco', 'Reference Code': 'CAW2111.FC6183', 'Price': '4390', 'Box': 'No', 'Year': '2011', 'Product code': '320524', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Leather Alligator Grain - Blue (Adjustable)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR5A8Y.FT6072/47936/item/218506', 'Model': 'Carrera', 'Reference Code': 'CAR5A8Y.FT6072', 'Price': '9980', 'Box': 'Yes', 'Year': '2016', 'Product code': '218506', 'Case size': '45 mm', 'Case material': 'Titanium', 'Bracelet': 'Leather - Brown & Rubber (Adjustable)', 'Dial type': 'Skeleton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Grand%20Carrera/WAV511E.BA0900/9093/item/315348', 'Model': 'Grand Carrera', 'Reference Code': 'WAV511E.BA0900', 'Price': '3790', 'Box': 'Yes', 'Year': '2018', 'Product code': '315348', 'Case size': '40 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Brown Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN2013.FC6483/60737/item/331694', 'Model': 'Carrera', 'Reference Code': 'CBN2013.FC6483', 'Price': '5255', 'Box': 'Yes', 'Year': '2023', 'Product code': '331694', 'Case size': '42 mm', 'Case material': 'Steel', 'Dial type': 'Silver Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2114.FC6486/48088/item/319773', 'Model': 'Monaco', 'Reference Code': 'CBL2114.FC6486', 'Price': '6075', 'Box': 'Yes', 'Year': '2020', 'Product code': '319773', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Red Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV2111/61425/item/278135', 'Model': 'Carrera', 'Reference Code': 'CV2111', 'Price': '3310', 'Box': 'Yes', 'Year': '2012', 'Product code': '278135', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Black Baton', 'Water resistance': '50 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CV2A81.FC6237/28763/item/310196', 'Model': 'Carrera', 'Reference Code': 'CV2A81.FC6237', 'Price': '3190', 'Box': 'No', 'Year': '2020', 'Product code': '310196', 'Case size': '43 mm', 'Case material': 'Titanium', 'Dial type': 'Black Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2A5B.FT6044/33189/item/284258', 'Model': 'Carrera', 'Reference Code': 'CAR2A5B.FT6044', 'Price': '7520', 'Box': 'Yes', 'Year': '2018', 'Product code': '284258', 'Case size': '45 mm', 'Case material': 'Rose Gold', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Autavia/CBE2110.FC8226/33758/item/333645', 'Model': 'Autavia', 'Reference Code': 'CBE2110.FC8226', 'Price': '3345', 'Box': 'Yes', 'Year': '2020', 'Product code': '333645', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Brown (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAL5112.FC6298/23111/item/318228', 'Model': 'Monaco', 'Reference Code': 'CAL5112.FC6298', 'Price': '8120', 'Box': 'Yes', 'Year': '2015', 'Product code': '318228', 'Case size': '40 mm', 'Case material': 'Steel', 'Dial type': 'Grey', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW211P.FC6356/28477/item/330610', 'Model': 'Monaco', 'Reference Code': 'CAW211P.FC6356', 'Price': '4625', 'Box': 'Yes', 'Year': '2017', 'Product code': '330610', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Autavia/CBE2118.FC8246/60403/item/333924', 'Model': 'Autavia', 'Reference Code': 'CBE2118.FC8246', 'Price': '4600', 'Box': 'Yes', 'Year': '2024', 'Product code': '333924', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Black', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR2A11.BA0799/26885/item/311158', 'Model': 'Carrera', 'Reference Code': 'CAR2A11.BA0799', 'Price': '2940', 'Box': 'Yes', 'Year': '2014', 'Product code': '311158', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 19.5 cm)', 'Dial type': 'Grey Arabic', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Link/CAT2012.BA0952/28142/item/253366', 'Model': 'Link', 'Reference Code': 'CAT2012.BA0952', 'Price': '2160', 'Box': 'No', 'Year': '2012', 'Product code': '253366', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18.5 cm)', 'Dial type': 'Black Dial, Black Sub Dials', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WV211B.BA0787/2928/item/312533', 'Model': 'Carrera', 'Reference Code': 'WV211B.BA0787', 'Price': '1535', 'Box': 'No', 'Year': '2015', 'Product code': '312533', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Black Baton', 'Water resistance': '50 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Grand%20Carrera/CAV518B.FC6237/9091/item/311455', 'Model': 'Grand Carrera', 'Reference Code': 'CAV518B.FC6237', 'Price': '3550', 'Box': 'Yes', 'Year': '2009', 'Product code': '311455', 'Case size': '43 mm', 'Case material': 'Titanium', 'Dial type': 'Black Dial, Black Sub Dials', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW211P.FC6356/28477/item/321172', 'Model': 'Monaco', 'Reference Code': 'CAW211P.FC6356', 'Price': '5015', 'Box': 'Yes', 'Year': '2021', 'Product code': '321172', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW2111.FC6183/14266/item/319379', 'Model': 'Monaco', 'Reference Code': 'CAW2111.FC6183', 'Price': '4495', 'Box': 'No', 'Year': '2015', 'Product code': '319379', 'Case size': '39 mm', 'Case material': 'Steel', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WBP2110.BA0627/56833/item/336273', 'Model': 'Aquaracer', 'Reference Code': 'WBP2110.BA0627', 'Price': '2425', 'Box': 'Yes', 'Year': '2024', 'Product code': '336273', 'Case size': '40 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 17.5 cm)', 'Dial type': 'Black Baton', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WAJ2150.FT6015/15249/item/324165', 'Model': 'Aquaracer', 'Reference Code': 'WAJ2150.FT6015', 'Price': '2255', 'Box': 'Yes', 'Year': '2001', 'Product code': '324165', 'Case size': '43 mm', 'Case material': 'Steel & Rose Gold', 'Bracelet': 'Rubber - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '500 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN2A5A.FC6481/50104/item/301621', 'Model': 'Carrera', 'Reference Code': 'CBN2A5A.FC6481', 'Price': '5160', 'Box': 'Yes', 'Year': '2021', 'Product code': '301621', 'Case size': '44 mm', 'Case material': 'Steel & Rose Gold', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CAW2111.FC6356/37018/item/332899', 'Model': 'Monaco', 'Reference Code': 'CAW2111.FC6356', 'Price': '4810', 'Box': 'Yes', 'Year': '2017', 'Product code': '332899', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Link/CAT2012.BA0952/28142/item/328903', 'Model': 'Link', 'Reference Code': 'CAT2012.BA0952', 'Price': '2465', 'Box': 'Yes', 'Year': '2014', 'Product code': '328903', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18.5 cm)', 'Dial type': 'Black Dial, Black Sub Dials', 'Water resistance': '200 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Autavia/CBE2110.FC8226/33758/item/319955', 'Model': 'Autavia', 'Reference Code': 'CBE2110.FC8226', 'Price': '3550', 'Box': 'Yes', 'Year': '2019', 'Product code': '319955', 'Case size': '42 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Brown & Rubber (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CAR201M.FT6156/44760/item/337186', 'Model': 'Carrera', 'Reference Code': 'CAR201M.FT6156', 'Price': '3145', 'Box': 'Yes', 'Year': '2020', 'Product code': '337186', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Rubber - Red (Adjustable)', 'Dial type': 'Skeleton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Grand%20Carrera/CAV511B.BA0902/7896/item/308090', 'Model': 'Grand Carrera', 'Reference Code': 'CAV511B.BA0902', 'Price': '3195', 'Box': 'No', 'Year': '2001', 'Product code': '308090', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Silver Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBG2A10.BA0654/50580/item/332025', 'Model': 'Carrera', 'Reference Code': 'CBG2A10.BA0654', 'Price': '4840', 'Box': 'Yes', 'Year': '2020', 'Product code': '332025', 'Case size': '45 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Skeleton Black Dial', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/WBP208B.BF0631/51839/item/294087', 'Model': 'Aquaracer', 'Reference Code': 'WBP208B.BF0631', 'Price': '3490', 'Box': 'Yes', 'Year': '2023', 'Product code': '294087', 'Case size': '43 mm', 'Case material': 'Titanium', 'Bracelet': 'Titanium (length 19.8 cm)', 'Dial type': 'Green', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2180.FC6497/55927/item/330370', 'Model': 'Monaco', 'Reference Code': 'CBL2180.FC6497', 'Price': 'N/A', 'Box': 'Yes', 'Year': '2024', 'Product code': '330370', 'Case size': '39 mm', 'Case material': 'Titanium', 'Bracelet': 'Alligator - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBG2011.BA0662/56282/item/312563', 'Model': 'Carrera', 'Reference Code': 'CBG2011.BA0662', 'Price': '4750', 'Box': 'Yes', 'Year': '2020', 'Product code': '312563', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 16 cm)', 'Dial type': 'Skeleton Blue Dial', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Monaco/CBL2111.FC6453/63992/item/320432', 'Model': 'Monaco', 'Reference Code': 'CBL2111.FC6453', 'Price': '5955', 'Box': 'No', 'Year': '2020', 'Product code': '320432', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Calf - Blue (Adjustable)', 'Dial type': 'Blue Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Aquaracer/CAY2110.BA0927/30947/item/312749', 'Model': 'Aquaracer', 'Reference Code': 'CAY2110.BA0927', 'Price': '2145', 'Box': 'Yes', 'Year': '2015', 'Product code': '312749', 'Case size': '43 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 17.5 cm)', 'Dial type': 'Black Baton', 'Water resistance': '300 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/WAR5010.BA0723/27026/item/301811', 'Model': 'Carrera', 'Reference Code': 'WAR5010.BA0723', 'Price': '2070', 'Box': 'Yes', 'Year': '2015', 'Product code': '301811', 'Case size': '41 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 18 cm)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera%20Ladies/WAR1115.FC6392/59568/item/261471', 'Model': 'Carrera Ladies', 'Reference Code': 'WAR1115.FC6392', 'Price': '2225', 'Box': 'No', 'Year': '2020', 'Product code': '261471', 'Case size': '39 mm', 'Case material': 'Steel', 'Bracelet': 'Leather - Black (Adjustable)', 'Dial type': 'Black Baton', 'Water resistance': '100 m'}
# {'URL': 'https://www.watchfinder.com/Tag%20Heuer/Carrera/CBN2A10.BA0643/49220/item/334316', 'Model': 'Carrera', 'Reference Code': 'CBN2A10.BA0643', 'Price': '4450', 'Box': 'Yes', 'Year': '2021', 'Product code': '334316', 'Case size': '44 mm', 'Case material': 'Steel', 'Bracelet': 'Steel (length 17 cm)', 'Dial type': 'Green Baton', 'Water resistance': '100 m'}
# Extraction complete!
# Converting data to DataFrame...
# Data conversion complete!

# %%
results_df = results_df[results_df['Price'] != 'N/A']
results_df.to_csv('watchfinder_scraping_results.csv', index=False)
